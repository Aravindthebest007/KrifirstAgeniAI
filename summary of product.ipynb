# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindthebest007/KrifirstAgeniAI/blob/main/summary%20of%20product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Analyze the marketing strategy, product selection, and messaging style from the "asos_products.csv" file and generate a downloadable PowerPoint presentation summarizing the findings.

# %% [markdown]
# ## Load and inspect the data
#
# ### Subtask:
# Load the `asos_products.csv` file into a pandas DataFrame and display the first few rows and the columns and their data types to understand the data structure.

# %% [markdown]
# **Reasoning**:
# Load the data into a pandas DataFrame and display the first few rows, column names and their data types to understand the data structure.

# %%
import pandas as pd

try:
    df = pd.read_csv('https://raw.githubusercontent.com/Aravindthebest007/KrifirstAgeniAI/refs/heads/main/asos_products.csv')
    display(df.head())
    display(df.info())
except FileNotFoundError:
    print("Error: 'asos_products.csv' not found. Please upload the file or provide the correct path.")
# Out:
#                Product ID                   Name         Category  \
# 0  ASOS-UK-COA-SS25-00001            Casual Coat            Coats
# 1  ASOS-UK-HAN-SS25-00002        Stylish Handbag         Handbags
# 2  ASOS-UK-TOP-SS25-00003  Casual Tops & T-shirt  Tops & T-shirts
# 3  ASOS-UK-SHO-SS25-00004           Classic Shoe            Shoes
# 4  ASOS-UK-COA-SS25-00005           Elegant Coat            Coats
#
#   Colour Palette  Pattern Size Options             Occasion          Brand  \
# 0         Winter  Striped        XS, L             Everyday    ASOS Design
# 1           Warm    Plain         M, L               Formal   Bimba y Lola
# 2        Summery    Plain       XXL, L               Casual  Kat the Label
# 3        Neutral  Striped    L, XL, XS               Casual   Bimba y Lola
# 4         Winter  Striped         S, M  Party/Occasion Wear           TALA
#
#     Price                                        Description Customer Reviews  \
# ...

# %% [markdown]
# ### Analyze Product Categories and Sales Target Customers

# %%
# Analyze the distribution of product categories
print("Product Category Distribution:")
display(df['Category'].value_counts())

# Analyze the distribution of sales target customers
print("\nSales Target Customer Distribution:")
display(df['Sales Target Customer'].value_counts())
# Out:
# Product Category Distribution:
# Category
# Coats              19
# Dresses            16
# Shoes              15
# Handbags           14
# Trousers           13
# Tops & T-shirts    10
# Skirts              7
# Jackets             6
# Name: count, dtype: int64
# Sales Target Customer Distribution:
# Sales Target Customer
# Male           32
# Unisex         19
# Female         18
# Gen Z          16
# Millennials    15
# Name: count, dtype: int64

# %%
# Summary statistics for numerical columns
display(df.describe())

# Summary statistics for all columns, including categorical
display(df.describe(include='all'))
# Out:
#             Price
# count  100.000000
# mean   189.083500
# std     97.551324
# min     13.940000
# 25%    108.560000
# 50%    192.095000
# 75%    273.567500
# max    347.230000
#                     Product ID          Name Category Colour Palette Pattern  \
# count                      100           100      100            100     100
# unique                     100            35        8              8       5
# top     ASOS-UK-COA-SS25-00001  Elegant Coat    Coats         Pastel   Plain
# freq                         1             7       19             17      26
# mean                       NaN           NaN      NaN            NaN     NaN
# std                        NaN           NaN      NaN            NaN     NaN
# min                        NaN           NaN      NaN            NaN     NaN
# 25%                        NaN           NaN      NaN            NaN     NaN
# 50%                        NaN           NaN      NaN            NaN     NaN
# ...

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because the file was not found. I will try to list the files in the current directory to check if the file exists and its name.

# %%
# %ls
# Out:
# sample_data/

# %% [markdown]
# ## Load and inspect the data
#
# ### Subtask:
# Load the `asos_products.csv` file into a pandas DataFrame and display the first few rows and the columns and their data types to understand the data structure.

# %% [markdown]
# **Reasoning**:
# Load the data into a pandas DataFrame and display the first few rows along with the column information.

# %%
import pandas as pd

df = pd.read_csv('/content/asos_products.csv')
display(df.head())
display(df.info())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1653840254.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('/content/asos_products.csv')
#       4 display(df.head())
#       5 display(df.info())
#
# ...

# %% [markdown]
# **Reasoning**:
# The file was not found in the previous attempt. I need to check the available files in the environment to locate the correct file path.

# %%
# %ls /content/sample_data/
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %% [markdown]
# **Reasoning**:
# The previous attempt to locate the file in `/content/sample_data/` was unsuccessful. I need to check the root `/content/` directory for the file.

# %%
# %ls /content/
# Out:
# sample_data/

# %% [markdown]
# ## Load and inspect the data
#
# ### Subtask:
# Load the `asos_products.csv` file into a pandas DataFrame and display the first few rows and the columns and their data types to understand the data structure.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The required file `asos_products.csv` was not found in the specified directories (`/content/` and `/content/sample_data/`).
# *   Due to the missing file, the data loading and initial inspection steps could not be completed.
#
# ### Insights or Next Steps
#
# *   Verify the correct file path and name for `asos_products.csv`.
# *   Ensure the `asos_products.csv` file is present in the accessible file system before attempting to load it again.
